# %%
import scanpy as sc

# %%
adata = sc.read("../../processed_data/integrated_data/20241021_full_log_count.h5ad")

# %%
sc.pp.log1p(adata)

# %%
sc.pl.umap(adata,color=["Sp7","Ambn"],use_raw=False)
