# %%
import pandas as pd

# %%
feather = pd.read_feather("../../../../disk1/database/RcisTarget/v10_scenic/mm10_")

# %%
feather
# Out:
#       chr10:100001588-100001754  chr10:100004590-100004749  \
# 0                        635378                     961923
# 1                        294685                      79408
# 2                        772320                     771634
# 3                        577456                     435983
# 4                        976643                     795153
# ...                         ...                        ...
# 5027                     603227                     564886
# 5028                     290832                     445232
# 5029                     267827                     674988
# 5030                     374827                      57021
# 5031                     433070                     915836
#
#       chr10:100009729-100010013  chr10:100010349-100010586  \
# 0                         81883                     335281
# 1                        809215                     519946
# 2                        289363                     277952
# ...

# %%
motifs  = feather.loc[:,"motifs"]

# %%
motifs
# Out:
# 0                 bergman__Su_H_
# 1                  bergman__croc
# 2                   bergman__pho
# 3                   bergman__tll
# 4                c2h2_zfs__M0369
#                   ...
# 5027    yetfasco__TBP-TFIIA_1328
# 5028    yetfasco__TBP-TFIIB_1329
# 5029      yetfasco__YFL044C_1166
# 5030      yetfasco__YGL192W_1000
# 5031      yetfasco__YPR086W_1327
# Name: motifs, Length: 5032, dtype: object
