# %%
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append("../utils/")
import pre_processing

# %%
save_dir = "../../process/pre-intergration/normalization_1019/"

# %%
adata = sc.read("../../process/pre-intergration/big_data/20241019_mergeall_normalized_step2.h5ad")

# %%
path_cells_removed_data = "../../process/pre-intergration/big_data/20241019_filtered_data.h5ad"
path_cells_keep_data = "../../process/pre-intergration/big_data/20241019_lop10_hvg.h5ad"

# %%
adata.obs["Project"].unique()
# Out:
# ['ToothNc_Junjun', 'ToothNiche_Hong', 'Molar_Raju', 'CAGE_Chiba', 'Epi_Chiba', ..., 'Peridontal_Nagata', 'Runx2_Shuo', 'Molar_Qian', 'MolarE145_Outie', 'MolarP12_Tomoko']
# Length: 17
# Categories (16, object): ['Atlas_Jan', 'CAGE_Chiba', 'Cycling_Rapolas', 'Epi_Chiba', ..., 'Runx2_Shuo', 'ToothNc_Junjun', 'ToothNiche_Hong', 'Tooth_Zheng']

# %%
adata.obs[adata.obs["Project"].isnull()]
# Out:
#                                                   orig.ident  nCount_RNA  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2  Cycling_Rapolas_injury      6327.0
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2  Cycling_Rapolas_injury      2664.0
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2  Cycling_Rapolas_injury     12177.0
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2  Cycling_Rapolas_injury      3687.0
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2  Cycling_Rapolas_injury      7743.0
# ...                                                      ...         ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1              Follicle_Akira      8652.0
# Follile_Akira_TTTGTCAAGGGATACC-1              Follicle_Akira     10327.0
# Follile_Akira_TTTGTCACACCTGGTG-1              Follicle_Akira     12843.0
# Follile_Akira_TTTGTCACATGTTCCC-1              Follicle_Akira       848.0
# Follile_Akira_TTTGTCAGTTCTCATT-1              Follicle_Akira      1269.0
#
#                                       nFeature_RNA coarse_anno_1  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2          2468    Epithelium
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2          1424    Epithelium
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2          3642    Epithelium
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2          1720    Epithelium
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2          2967    Epithelium
# ...                                            ...           ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1              2744    Mesenchyme
# Follile_Akira_TTTGTCAAGGGATACC-1              3510    Mesenchyme
# Follile_Akira_TTTGTCACACCTGGTG-1              3717   Endothelium
# Follile_Akira_TTTGTCACATGTTCCC-1               573   Endothelium
# Follile_Akira_TTTGTCAGTTCTCATT-1               766           RBC
#
#                                       total_counts  log10_total_counts  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2        6327.0            3.801198
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2        2664.0            3.425534
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2       12177.0            4.085540
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2        3687.0            3.566673
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2        7743.0            3.888909
# ...                                            ...                 ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1            8652.0            3.937117
# Follile_Akira_TTTGTCAAGGGATACC-1           10327.0            4.013974
# Follile_Akira_TTTGTCACACCTGGTG-1           12843.0            4.108666
# Follile_Akira_TTTGTCACATGTTCCC-1             848.0            2.928396
# Follile_Akira_TTTGTCAGTTCTCATT-1            1269.0            3.103462
#
#                                       n_genes_detected  mito_frac  ribo_frac  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2              2468   0.017386   0.210210
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2              1424   0.023273   0.231982
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2              3642   0.021270   0.211218
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2              1720   0.019799   0.193382
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2              2967   0.022214   0.169443
# ...                                                ...        ...        ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1                  2744   0.024041   0.183541
# Follile_Akira_TTTGTCAAGGGATACC-1                  3510   0.025855   0.171202
# Follile_Akira_TTTGTCACACCTGGTG-1                  3717   0.023359   0.217550
# Follile_Akira_TTTGTCACATGTTCCC-1                   573   0.015330   0.221698
# Follile_Akira_TTTGTCAGTTCTCATT-1                   766   0.042553   0.208826
#
#                                          compl  ...  Development stage  \
# index                                           ...
# Cycling_Rapolas_AAACCTGAGATATACG-1_2  0.390074  ...                NaN
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2  0.534535  ...                NaN
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2  0.299088  ...                NaN
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2  0.466504  ...                NaN
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2  0.383185  ...                NaN
# ...                                        ...  ...                ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1      0.317152  ...                NaN
# Follile_Akira_TTTGTCAAGGGATACC-1      0.339886  ...                NaN
# Follile_Akira_TTTGTCACACCTGGTG-1      0.289418  ...                NaN
# Follile_Akira_TTTGTCACATGTTCCC-1      0.675708  ...                NaN
# Follile_Akira_TTTGTCAGTTCTCATT-1      0.603625  ...                NaN
#
#                                      Disease Strain Dissociation_enzyme  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2     NaN    NaN                 NaN
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2     NaN    NaN                 NaN
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2     NaN    NaN                 NaN
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2     NaN    NaN                 NaN
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2     NaN    NaN                 NaN
# ...                                      ...    ...                 ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1         NaN    NaN                 NaN
# Follile_Akira_TTTGTCAAGGGATACC-1         NaN    NaN                 NaN
# Follile_Akira_TTTGTCACACCTGGTG-1         NaN    NaN                 NaN
# Follile_Akira_TTTGTCACATGTTCCC-1         NaN    NaN                 NaN
# Follile_Akira_TTTGTCAGTTCTCATT-1         NaN    NaN                 NaN
#
#                                      Machine Species Related assay Journal  \
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2     NaN     NaN           NaN     NaN
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2     NaN     NaN           NaN     NaN
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2     NaN     NaN           NaN     NaN
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2     NaN     NaN           NaN     NaN
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2     NaN     NaN           NaN     NaN
# ...                                      ...     ...           ...     ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1         NaN     NaN           NaN     NaN
# Follile_Akira_TTTGTCAAGGGATACC-1         NaN     NaN           NaN     NaN
# Follile_Akira_TTTGTCACACCTGGTG-1         NaN     NaN           NaN     NaN
# Follile_Akira_TTTGTCACATGTTCCC-1         NaN     NaN           NaN     NaN
# Follile_Akira_TTTGTCAGTTCTCATT-1         NaN     NaN           NaN     NaN
#
#                                      Data Source Data location
# index
# Cycling_Rapolas_AAACCTGAGATATACG-1_2         NaN           NaN
# Cycling_Rapolas_AAACCTGAGATCCTGT-1_2         NaN           NaN
# Cycling_Rapolas_AAACCTGAGATGGGTC-1_2         NaN           NaN
# Cycling_Rapolas_AAACCTGCAAGTAATG-1_2         NaN           NaN
# Cycling_Rapolas_AAACCTGCACCCTATC-1_2         NaN           NaN
# ...                                          ...           ...
# Follile_Akira_TTTGTCAAGCGTTCCG-1             NaN           NaN
# Follile_Akira_TTTGTCAAGGGATACC-1             NaN           NaN
# Follile_Akira_TTTGTCACACCTGGTG-1             NaN           NaN
# Follile_Akira_TTTGTCACATGTTCCC-1             NaN           NaN
# Follile_Akira_TTTGTCAGTTCTCATT-1             NaN           NaN
#
# [8601 rows x 36 columns]

# %%
scMeta = pd.read_csv("../../processed_data/metadata/scMetadata_latest.csv",index_col=0)

# %%
scMeta
# Out:
#                                                 orig.ident  nCount_RNA  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   ToothNc_Junjun_E13.5      4461.0
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   ToothNc_Junjun_E13.5      2587.0
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   ToothNc_Junjun_E13.5     14429.0
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   ToothNc_Junjun_E13.5      2657.0
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   ToothNc_Junjun_E13.5     10948.0
# ...                                                    ...         ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2  MolarP12_Tomoko_homo      9761.0
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2  MolarP12_Tomoko_homo      8938.0
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2  MolarP12_Tomoko_homo      6486.0
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2  MolarP12_Tomoko_homo     12096.0
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2  MolarP12_Tomoko_homo     15565.0
#
#                                       nFeature_RNA coarse_anno_1  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1           1712    Epithelium
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1           1233    Mesenchyme
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1           3934    Epithelium
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1           1418           RBC
# ToothNc_Junjun_AAACCCACACAACGAG-1_1           3213   Endothelium
# ...                                            ...           ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2          3318  Perivascular
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2          3105  Perivascular
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2          2708        Neuron
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2          3596        Neuron
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2          2956        Immune
#
#                                       total_counts  log10_total_counts  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1         4461.0            3.649432
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1         2587.0            3.412796
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1        14429.0            4.159236
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1         2657.0            3.424392
# ToothNc_Junjun_AAACCCACACAACGAG-1_1        10948.0            4.039335
# ...                                            ...                 ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2        9761.0            3.989494
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2        8938.0            3.951240
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2        6486.0            3.811977
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2       12096.0            4.082642
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2       15565.0            4.192149
#
#                                       n_genes_detected  mito_frac  ribo_frac  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1               1712   0.071509   0.298364
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1               1233   0.143796   0.187089
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1               3934   0.045533   0.231478
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1               1418   0.062476   0.212269
# ToothNc_Junjun_AAACCCACACAACGAG-1_1               3213   0.074351   0.272653
# ...                                                ...        ...        ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2              3318   0.052351   0.169655
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2              3105   0.033229   0.092638
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2              2708   0.049337   0.103299
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2              3596   0.068287   0.085565
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2              2956   0.010215   0.307613
#
#                                          compl  ...  Development stage  \
# index                                           ...
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   0.383770  ...                Bud
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   0.476614  ...                Bud
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   0.272645  ...                Bud
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   0.533685  ...                Bud
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   0.293478  ...                Bud
# ...                                        ...  ...                ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2  0.339924  ...               Bell
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2  0.347393  ...               Bell
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2  0.417515  ...               Bell
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2  0.297288  ...               Bell
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2  0.189913  ...               Bell
#
#                                            Disease    Strain  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   Not provided   C57BL/6
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   Not provided   C57BL/6
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   Not provided   C57BL/6
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   Not provided   C57BL/6
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   Not provided   C57BL/6
# ...                                            ...       ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2  Not provided  C57BL/6J
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2  Not provided  C57BL/6J
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2  Not provided  C57BL/6J
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2  Not provided  C57BL/6J
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2  Not provided  C57BL/6J
#
#                                                             Dissociation_enzyme  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   Dispase (Roche) and Collagenase I (Gibco)
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   Dispase (Roche) and Collagenase I (Gibco)
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   Dispase (Roche) and Collagenase I (Gibco)
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   Dispase (Roche) and Collagenase I (Gibco)
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   Dispase (Roche) and Collagenase I (Gibco)
# ...                                                                         ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2                              collagenase D
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2                              collagenase D
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2                              collagenase D
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2                              collagenase D
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2                              collagenase D
#
#                                            Machine       Species  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   10X(unknown)  Mus Musculus
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   10X(unknown)  Mus Musculus
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   10X(unknown)  Mus Musculus
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   10X(unknown)  Mus Musculus
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   10X(unknown)  Mus Musculus
# ...                                            ...           ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2       10X(v3)  Mus musculus
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2       10X(v3)  Mus musculus
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2       10X(v3)  Mus musculus
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2       10X(v3)  Mus musculus
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2       10X(v3)  Mus musculus
#
#                                                                           Related assay  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   Spatiotemporal single-cell regulatory atlas re...
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   Spatiotemporal single-cell regulatory atlas re...
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   Spatiotemporal single-cell regulatory atlas re...
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   Spatiotemporal single-cell regulatory atlas re...
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   Spatiotemporal single-cell regulatory atlas re...
# ...                                                                                 ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2  Coupling of angiogenesis and odontogenesis orc...
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2  Coupling of angiogenesis and odontogenesis orc...
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2  Coupling of angiogenesis and odontogenesis orc...
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2  Coupling of angiogenesis and odontogenesis orc...
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2  Coupling of angiogenesis and odontogenesis orc...
#
#                                                    Journal Data Source  \
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1   Nature Communication   GSE189381
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1   Nature Communication   GSE189381
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1   Nature Communication   GSE189381
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1   Nature Communication   GSE189381
# ToothNc_Junjun_AAACCCACACAACGAG-1_1   Nature Communication   GSE189381
# ...                                                    ...         ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2          Not provided   GSE181175
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2          Not provided   GSE181175
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2          Not provided   GSE181175
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2          Not provided   GSE181175
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2          Not provided   GSE181175
#
#                                                             Data location
# index
# ToothNc_Junjun_AAACCCAAGCCTGTCG-1_1    preprocess_data/ToothNc_Junjun.Rds
# ToothNc_Junjun_AAACCCAAGCTAAGTA-1_1    preprocess_data/ToothNc_Junjun.Rds
# ToothNc_Junjun_AAACCCAAGTGATTCC-1_1    preprocess_data/ToothNc_Junjun.Rds
# ToothNc_Junjun_AAACCCACAAGATTGA-1_1    preprocess_data/ToothNc_Junjun.Rds
# ToothNc_Junjun_AAACCCACACAACGAG-1_1    preprocess_data/ToothNc_Junjun.Rds
# ...                                                                   ...
# MolarP12_Tomoko_TTTGGTTGTTGTCAGT-1_2  preprocess_data/MolarP12_Tomoko.Rds
# MolarP12_Tomoko_TTTGGTTTCCGTTTCG-1_2  preprocess_data/MolarP12_Tomoko.Rds
# MolarP12_Tomoko_TTTGGTTTCTAACACG-1_2  preprocess_data/MolarP12_Tomoko.Rds
# MolarP12_Tomoko_TTTGTTGAGAGGTATT-1_2  preprocess_data/MolarP12_Tomoko.Rds
# MolarP12_Tomoko_TTTGTTGTCTTACCGC-1_2  preprocess_data/MolarP12_Tomoko.Rds
#
# [371467 rows x 36 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 371467 × 36303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'coarse_anno_1', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'Sample', 'Project', 'Core_datasets', 'Mandibular_Maxillary', 'Molar_Incisor', 'Tooth position', 'Histology', 'Sex', 'Gene Type', 'Knockout_gene', 'Cre', 'Treatment', 'FACs', 'Age', 'Stage', 'Development stage', 'Disease', 'Strain', 'Dissociation_enzyme', 'Machine', 'Species', 'Related assay', 'Journal', 'Data Source', 'Data location'
#     var: 'gene_symbols', 'n_cells'
#     uns: 'X_name'
#     layers: 'counts', 'logcounts'

# %%
adata = pre_processing.merge_metadata(adata,scMeta)
# Out:
# Warning: Columns ['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'coarse_anno_1', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'Sample', 'Project', 'Core_datasets', 'Mandibular_Maxillary', 'Molar_Incisor', 'Tooth position', 'Histology', 'Sex', 'Gene Type', 'Knockout_gene', 'Cre', 'Treatment', 'FACs', 'Age', 'Stage', 'Development stage', 'Disease', 'Strain', 'Dissociation_enzyme', 'Machine', 'Species', 'Related assay', 'Journal', 'Data Source', 'Data location'] exist in both DataFrames. They will be replaced.

# %%
oldMeta = pd.read_csv("../../processed_data/metadata/20241008_metadata.csv",index_col=0)

# %%
oldMeta.columns
# Out:
# Index(['orig.ident', 'nCount_RNA', 'nFeature_RNA', 'coarse_anno_1',
#        'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac',
#        'ribo_frac', 'compl', 'size_factors', 'n_genes_by_counts',
#        'log1p_n_genes_by_counts', 'log1p_total_counts',
#        'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
#        'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'Sample'],
#       dtype='object')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 371467 × 36303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'coarse_anno_1', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'Sample', 'Project', 'Core_datasets', 'Mandibular_Maxillary', 'Molar_Incisor', 'Tooth position', 'Histology', 'Sex', 'Gene Type', 'Knockout_gene', 'Cre', 'Treatment', 'FACs', 'Age', 'Stage', 'Development stage', 'Disease', 'Strain', 'Dissociation_enzyme', 'Machine', 'Species', 'Related assay', 'Journal', 'Data Source', 'Data location'
#     var: 'gene_symbols', 'n_cells'
#     uns: 'X_name'
#     layers: 'counts', 'logcounts'

# %%
oldMeta["Sample"].value_counts()
# Out:
# Sample
# MolarE145_Outie              30930
# Tooth_Zheng_M2               20990
# ToothNc_Junjun_E14.5         18784
# ToothNc_Junjun_E16.5         18409
# Tooth_Zheng_M1               18371
# Incisor_Luo_E155WT           16388
# Molar_Raju_PN1_Mandibular    16045
# Molar_Raju_PN1_Maxillary     16006
# ToothNc_Junjun_E13.5         14619
# ToothNc_Junjun_P3.5          14188
# Incisor_Luo_E165             12367
# Incisor_Luo_E145             12239
# ToothNiche_Hong_E16.5        11289
# Incisor_Luo_E155Six1         11068
# ToothNiche_Hong_E14.5        10945
# ToothNc_Junjun_P7.5          10273
# Incisor_Zhang_Gli             9789
# Incisor_Zhang_WT              9515
# Molar_Raju_E15_Maxillary      8978
# ToothNiche_Hong_PN1           8866
# Molar_Qian                    8276
# ToothNiche_Hong_PN7           6766
# ToothNiche_Hong_E12.5         6306
# Epi_Chiba                     6249
# CAGE_Chiba_Mes                6017
# CAGE_Chiba_Epi                5973
# Molar_Raju_E15_Mandibular     5266
# Cycling_Rapolas_injury        4990
# centment                      4513
# Periontal_Nagta               4513
# Atlas_Jan_incisor_10x         4236
# Runx2_Shuo                    3828
# Cycling_Rapolas_control       3598
# MolarP12_Tomoko_ctrl          2960
# Atlas_Jan_incisor_SS2         2889
# MolarP12_Tomoko_homo          2204
# LYPD1_Chiba                   1687
# Atlas_Jan_molar_10x.2         1460
# Atlas_Jan_molar_10x.1          384
# Atlas_Jan_molar_SS2            195
# Name: count, dtype: int64

# %%
scMeta["Sample"].value_counts()
# Out:
# Sample
# MolarE145_Outie              30930
# Tooth_Zheng_M2               20990
# ToothNc_Junjun_E14.5         18784
# ToothNc_Junjun_E16.5         18409
# Tooth_Zheng_M1               18371
# Incisor_Luo_E155WT           16388
# Molar_Raju_PN1_Mandibular    16045
# Molar_Raju_PN1_Maxillary     16006
# ToothNc_Junjun_E13.5         14619
# ToothNc_Junjun_P3.5          14188
# Incisor_Luo_E165             12367
# Incisor_Luo_E145             12239
# ToothNiche_Hong_E16.5        11289
# Incisor_Luo_E155Six1         11068
# ToothNiche_Hong_E14.5        10945
# ToothNc_Junjun_P7.5          10273
# Incisor_Zhang_Gli             9789
# Incisor_Zhang_WT              9515
# Molar_Raju_E15_Maxillary      8978
# ToothNiche_Hong_PN1           8866
# Molar_Qian                    8276
# ToothNiche_Hong_PN7           6766
# ToothNiche_Hong_E12.5         6306
# Epi_Chiba                     6249
# CAGE_Chiba_Mes                6017
# CAGE_Chiba_Epi                5973
# Molar_Raju_E15_Mandibular     5266
# Cycling_Rapolas_injury        4990
# Periontal_Nagta               4513
# Atlas_Jan_incisor_10x         4236
# Runx2_Shuo                    3828
# Follicle_Akira                3611
# Cycling_Rapolas_control       3598
# MolarP12_Tomoko_ctrl          2960
# Atlas_Jan_incisor_SS2         2889
# MolarP12_Tomoko_homo          2204
# LYPD1_Chiba                   1687
# Atlas_Jan_molar_10x.2         1460
# Atlas_Jan_molar_10x.1          384
# Atlas_Jan_molar_SS2            195
# Name: count, dtype: int64

# %%
scMeta.shape
# Out:
# (371467, 36)

# %%
set1 = scMeta["Sample"].unique()

# %%
set2 = meta.index[meta["Core_datasets"]]

# %%
difference = list(set(set1) - set(set2))

# %%
list(set(set2) - set(set1))
# Out:
# []

# %%
difference
# Out:
# ['Cycling_Rapolas_injury',
#  'Follicle_Akira',
#  'Incisor_Zhang_Gli',
#  'MolarP12_Tomoko_homo',
#  'Incisor_Luo_E155Six1']

# %%
oldMeta.shape
# Out:
# (372369, 19)

# %%
meta = pd.read_csv("../../data/metadata/metadata_latest.csv",index_col=0)

# %%
projectName = adata.obs["Project"].unique()
projectLen = len(adata.obs["Project"].unique())
gb_values = sns.color_palette("Set2", projectLen)
color_labels = adata.obs["Project"].unique()
color_map = dict(zip(color_labels, gb_values))

colors = []
for project in adata.obs["Project"].values:
    color = color_map.get(project)
    if color is None:
        # Provide a default color if None is found
        color = 'gray'  # or any other default color you prefer
    colors.append(color)

# Now create the scatter plot
plt.scatter(
    adata.obs.total_counts,
    adata.obs.size_factors,
    c=colors,
    s=1
)
plt.xlabel("Total Counts")
plt.ylabel("Size Factor")

# Set x and y limits
plt.xlim(0, 1000000)  # Replace with your desired limits for x-axis
plt.ylim(0, 110)     # Replace with your desired limits for y-axis
plt.savefig(f"{save_dir}/qc_sizefactor_count.pdf")
plt.show()

# %%
new_totals = np.array(np.sum(adata.X, axis=1))
plt.hist(np.log10(new_totals), bins=50)
plt.savefig(f"{save_dir}/qc_count_barplot")
plt.show()

# %%
sc.pp.calculate_qc_metrics(adata, inplace=True, layer="counts")

# %%
plt.scatter(
    adata.obs.n_genes_by_counts.values,
    np.log10(new_totals),
    s=1,
    c=list(map(lambda x: color_map.get(x), adata.obs["Project"].values)),
)


plt.xlabel("n genes detected")
plt.ylabel("log10(total counts after normalization)")
plt.title("norm total counts vs n genes detected")
plt.legend(labels="test")

plt.show()

# %%
plotdf = adata.obs
plotdf["new_totals_log"] = np.log10(new_totals)
sns.lmplot(
    x="n_genes_by_counts",
    y="new_totals_log",
    data=plotdf,
    hue="Project",
    fit_reg=False,
    scatter_kws={"s": 5},
)
plt.savefig(f"{save_dir}/qc_count_genedetect.pdf")
plt.show()

# %%
sns.lmplot(
    x="n_genes_by_counts",
    y="log1p_total_counts",
    data=adata.obs,
    hue="Project",
    fit_reg=False,
)
plt.savefig(f"{save_dir}/qc_count_genedetect2.pdf")
plt.show()

# %%
plt.hist(np.log10(new_totals), bins=50)
plt.xlabel("log10(total counts after normalization)")
plt.ylabel("n cells")
plt.vlines(x=5.6, ymin=0, ymax=40000, color="red")
plt.title("post-normalization total counts distribution")
plt.show()

# %%
plt.scatter(
    adata.obs.n_genes_by_counts.values,
    np.log10(new_totals),
    s=1,
)
plt.hlines(y=5.5,xmin=0, xmax=10000, color="red")
plt.xlabel("n genes detected")
plt.ylabel("log10(total counts after normalization)")
plt.title("norm total counts vs n genes detected")
plt.show()

# %%
# Create a hexbin plot
plt.hexbin(
    np.log10(adata.obs.size_factors),
    np.log10(adata.obs.n_genes_by_counts),
    gridsize=100,  # Adjust the size of the hexagons
    cmap='viridis',  # Choose a colormap
    mincnt=1,       # Minimum count to show a hexagon
    reduce_C_function=lambda c: np.log1p(c)
)

# Add a colorbar
plt.colorbar(label='Density')

# Add a vertical line
plt.vlines(x=np.log10(0.005), ymin=1, ymax=4, color="red")

# Set labels and title
plt.xlabel("SCRAN size factor")
plt.ylabel("n genes detected")
plt.title("SCRAN size factor vs n_genes_detected")

# Show the plot
plt.show()

# %%
# Calculate the 2D histogram
counts, xedges, yedges = np.histogram2d(
    np.log10(adata.obs.size_factors),
    np.log10(adata.obs.n_genes_by_counts),
    bins=30
)

# Log-transform the counts, adding a small constant to avoid log(0)
log_counts = np.log1p(counts)

# Create the hexbin plot
plt.imshow(
    log_counts.T,  # Transpose to match the orientation
    origin='lower',
    extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],
    cmap='viridis',  # Change to your preferred colormap
    aspect='auto'
)

# Add a colorbar
plt.colorbar(label='Log Density')

# Add a vertical line
plt.vlines(x=np.log10(0.005), ymin=yedges[0], ymax=yedges[-1], color="red")

# Set labels and title
plt.xlabel("SCRAN size factor")
plt.ylabel("n genes detected")
plt.title("SCRAN size factor vs n_genes_detected")

# Show the plot
plt.show()

# %%
plt.hist(np.log10(adata.obs.size_factors), bins=50)
plt.xlabel("log10(1/size_factor)")
plt.ylabel("ncells")
plt.vlines(x=np.log10(0.005), ymin=0, ymax=30000, color="red")
plt.title("SCRAN size factor distribution")
plt.show()

# %%
plt.scatter(np.log10(adata.obs.size_factors.values), np.log10(new_totals), s=1)
plt.vlines(x=np.log10(0.005), ymin=3.5, ymax=6, color="red")
plt.hlines(y=5.8, xmin=-2, xmax=1, color="red")
plt.xlabel("log10(size factor)")
plt.ylabel("log10(total count after SCRAN norm)")
plt.show()

# %%
cells_to_filter_out = adata[
    [
        norm_total_count_filter or sf_filter
        for norm_total_count_filter, sf_filter in zip(
            (new_totals > 10**5.8).flatten().tolist(), adata.obs.size_factors < 0.005
        )
    ],
    :,
].copy()

# %%
cells_to_filter_out
# Out:
# AnnData object with n_obs × n_vars = 316 × 36303
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'coarse_anno_1', 'total_counts', 'log10_total_counts', 'n_genes_detected', 'mito_frac', 'ribo_frac', 'compl', 'size_factors', 'Sample', 'Project', 'Core_datasets', 'Mandibular_Maxillary', 'Molar_Incisor', 'Tooth position', 'Histology', 'Sex', 'Gene Type', 'Knockout_gene', 'Cre', 'Treatment', 'FACs', 'Age', 'Stage', 'Development stage', 'Disease', 'Strain', 'Dissociation_enzyme', 'Machine', 'Species', 'Related assay', 'Journal', 'Data Source', 'Data location', 'new_totals_log', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'gene_symbols', 'n_cells', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'X_name'
#     layers: 'counts', 'logcounts'

# %%
    cells_to_filter_out.obs.Project.value_counts()
# Out:
# Project
# Molar_Qian     246
# LYPD1_Chiba     70
# Name: count, dtype: int64

# %%
cells_to_filter_out.write_h5ad(path_cells_removed_data)

# %%
filter_boolean = ~adata.obs.index.isin(cells_to_filter_out.obs.index)
adata = adata[filter_boolean, :].copy()

# %%
adata = adata[adata.obs["Core_datasets"]=="True"]

# %%
# function to calculate variances on *sparse* matrix
def vars(a, axis=None):
    """ Variance of sparse matrix a
    var = mean(a**2) - mean(a)**2
    """
    a_squared = a.copy()
    a_squared.data **= 2
    return a_squared.mean(axis) - np.square(a.mean(axis))
    
means = np.mean(adata.X, axis=0)
variances = vars(adata.X, axis=0)
dispersions = variances / means
min_mean = 0.03
# plot mean versus dispersion plot:
# now plot
plt.scatter(
    np.log1p(means).tolist()[0], np.log(dispersions).tolist()[0], s=2
)
plt.vlines(x=np.log1p(min_mean),ymin=-3,ymax=6,color='red')
plt.xlabel("log1p(mean)")
plt.ylabel("log(dispersion)")
plt.title("DISPERSION VERSUS MEAN")
plt.show()
# Out:
# /tmp/ipykernel_2118744/3263955989.py:12: RuntimeWarning: invalid value encountered in divide
#   dispersions = variances / means

# %%
sc.pp.highly_variable_genes(adata, batch_key="Sample",min_mean=min_mean, flavor="cell_ranger",n_top_genes=5000)
# Out:
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:251: UserWarning: If you pass `n_top_genes`, all cutoffs are ignored.
#   warnings.warn(msg, UserWarning)
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/zhanglab/micromamba/envs/py311/lib/python3.11/site-packages/anndata/_core/anndata.py:1145: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
adata.write_h5ad(path_cells_keep_data)
