# %%
import numpy as np
import scanpy as sc

from scib_metrics.benchmark import Benchmarker,BioConservation

# %matplotlib inline
import matplotlib
#from scib_metrics.nearest_neighbors import NeighborsOutput

# %%
import faiss

from scib_metrics.nearest_neighbors import NeighborsResults


def faiss_hnsw_nn(X: np.ndarray, k: int):
    """Gpu HNSW nearest neighbor search using faiss.

    See https://github.com/nmslib/hnswlib/blob/master/ALGO_PARAMS.md
    for index param details.
    """
    X = np.ascontiguousarray(X, dtype=np.float32)
    res = faiss.StandardGpuResources()
    M = 32
    index = faiss.IndexHNSWFlat(X.shape[1], M, faiss.METRIC_L2)
    gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
    gpu_index.add(X)
    distances, indices = gpu_index.search(X, k)
    del index
    del gpu_index
    # distances are squared
    return NeighborsResults(indices=indices, distances=np.sqrt(distances))


def faiss_brute_force_nn(X: np.ndarray, k: int):
    """Gpu brute force nearest neighbor search using faiss."""
    X = np.ascontiguousarray(X, dtype=np.float32)
    res = faiss.StandardGpuResources()
    index = faiss.IndexFlatL2(X.shape[1])
    gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
    gpu_index.add(X)
    distances, indices = gpu_index.search(X, k)
    del index
    del gpu_index
    # distances are squared
    return NeighborsOutput(indices=indices, distances=np.sqrt(distances))

# %%
adata=sc.read("../../process/pre-intergration/big_data/20241008_core_pp_log1p_half_gene_small_HVG.h5ad")

# %%
import os
import fnmatch
directory = "../../process/pre-intergration/hypertune/"

files = os.listdir(directory)
files = fnmatch.filter(files, "*.h5ad")
varList=list()

for file in files:
    print(os.path.join(directory, file))
    var_name = "scANVI_" + file.split("/")[-1].split("_")[1] + "_" + file.split("/")[-1].split("_")[3]
    print(var_name)
    varList.append(var_name)
# Out:
# ../../process/pre-intergration/hypertune/gene_2000_latent_30_umap.h5ad
# scANVI_2000_30
# ../../process/pre-intergration/hypertune/gene_8000_latent_10_umap.h5ad
# scANVI_8000_10
# ../../process/pre-intergration/hypertune/gene_3000_latent_15_umap.h5ad
# scANVI_3000_15
# ../../process/pre-intergration/hypertune/gene_1500_latent_20_umap.h5ad
# scANVI_1500_20
# ../../process/pre-intergration/hypertune/gene_4000_latent_4_umap.h5ad
# scANVI_4000_4
# ../../process/pre-intergration/hypertune/gene_4000_latent_20_umap.h5ad
# scANVI_4000_20
# ../../process/pre-intergration/hypertune/gene_3000_latent_30_umap.h5ad
# scANVI_3000_30
# ../../process/pre-intergration/hypertune/gene_1000_latent_15_umap.h5ad
# scANVI_1000_15
# ../../process/pre-intergration/hypertune/gene_4000_latent_15_umap.h5ad
# scANVI_4000_15
# ../../process/pre-intergration/hypertune/gene_3000_latent_20_umap.h5ad
# scANVI_3000_20
# ../../process/pre-intergration/hypertune/gene_1500_latent_15_umap.h5ad
# scANVI_1500_15
# ../../process/pre-intergration/hypertune/gene_8000_latent_4_umap.h5ad
# scANVI_8000_4
# ../../process/pre-intergration/hypertune/gene_1500_latent_6_umap.h5ad
# scANVI_1500_6
# ../../process/pre-intergration/hypertune/gene_2000_latent_10_umap.h5ad
# scANVI_2000_10
# ../../process/pre-intergration/hypertune/gene_5000_latent_30_umap.h5ad
# scANVI_5000_30
# ../../process/pre-intergration/hypertune/gene_5000_latent_15_umap.h5ad
# scANVI_5000_15
# ../../process/pre-intergration/hypertune/gene_3000_latent_4_umap.h5ad
# scANVI_3000_4

# %%
# update adata.obsm dictionary with the loaded data
for file in files:
    # extract the variable name from the file path
    var_name = "scANVI_" + file.split("/")[-1].split("_")[1] + "_" + file.split("/")[-1].split("_")[3]
    # read the data file
    data = sc.read(os.path.join(directory, file))
    # update the adata.obsm dictionary
    adata.obsm[var_name] = data.X

# %%
indiceList=[]
for var in varList:
    _,indices=np.unique(adata.obsm[var], axis=0, return_index=True)
    indiceList.append(indices)
common_values = indiceList[0]
for arr in indiceList[1:]:
    common_values = np.intersect1d(common_values, arr)

# %%
adata=adata[common_values,]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 50766 × 2000
#     obs: 'Age', 'Core_datasets', 'Cre', 'Data Source', 'Data location', 'Development stage', 'Disease', 'Dissociation_enzyme', 'FACs', 'Gene Type', 'Histology', 'Journal', 'Knownout_gene', 'Machine', 'Mandibular_Maxillary', 'Molar_Incisor', 'Project', 'Related assay', 'Sample', 'Sex', 'Species', 'Stage', 'Strain', 'Tooth position', 'Treatment', 'coarse_anno_1', 'compl', 'log10_total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'mito_frac', 'nCount_RNA', 'nFeature_RNA', 'n_genes_by_counts', 'n_genes_detected', 'orig.ident', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'pct_counts_in_top_50_genes', 'ribo_frac', 'size_factors', 'total_counts'
#     var: 'gene_symbol', 'gene_symbols', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'X_name', 'hvg', 'log1p'
#     obsm: 'scANVI_2000_30', 'scANVI_8000_10', 'scANVI_3000_15', 'scANVI_1500_20', 'scANVI_4000_4', 'scANVI_4000_20', 'scANVI_3000_30', 'scANVI_1000_15', 'scANVI_4000_15', 'scANVI_3000_20', 'scANVI_1500_15', 'scANVI_8000_4', 'scANVI_1500_6', 'scANVI_2000_10', 'scANVI_5000_30', 'scANVI_5000_15', 'scANVI_3000_4'
#     layers: 'counts'

# %%
biocons = BioConservation(isolated_labels=False)
bm = Benchmarker(
    adata,
    batch_key="Sample",
    label_key="n_genes_by_counts",
    embedding_obsm_keys=varList,
    bio_conservation_metrics=biocons,
    n_jobs=-1,
)

# %%
bm.benchmark()
# Out:
# /home/gilberthan/anaconda3/envs/py311/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:374: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
# /home/gilberthan/anaconda3/envs/py311/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:314: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm["X_pca"] = X_pca
# Computing neighbors: 100%|██████████| 17/17 [07:15<00:00, 25.62s/it]
# Embeddings:   0%|          | 0/17 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|          | 0/10 [00:00<?, ?it/s, Bio conservation: nmi_ari_cluster_labels_kmeans]An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#
# Metrics:  10%|█         | 1/10 [45:19<6:47:57, 2719.71s/it, Bio conservation: nmi_ari_cluster_labels_kmeans]
# Metrics:  10%|█         | 1/10 [45:19<6:47:57, 2719.71s/it, Bio conservation: silhouette_label]
# Metrics:  20%|██        | 2/10 [45:42<2:31:08, 1133.54s/it, Bio conservation: silhouette_label]
# Metrics:  20%|██        | 2/10 [45:42<2:31:08, 1133.54s/it, Bio conservation: clisi_knn]
# Metrics:  30%|███       | 3/10 [45:45<1:12:00, 617.27s/it, Bio conservation: clisi_knn]
# Metrics:  30%|███       | 3/10 [45:45<1:12:00, 617.27s/it, Batch correction: silhouette_batch]
# Metrics:  40%|████      | 4/10 [46:11<38:21, 383.61s/it, Batch correction: silhouette_batch]
# Metrics:  40%|████      | 4/10 [46:11<38:21, 383.61s/it, Batch correction: ilisi_knn]
# Metrics:  50%|█████     | 5/10 [46:11<20:27, 245.51s/it, Batch correction: ilisi_knn]
# Metrics:  50%|█████     | 5/10 [46:11<20:27, 245.51s/it, Batch correction: kbet_per_label]
# INFO     500 consists of a single batch or is too small. Skip.
# INFO     501 consists of a single batch or is too small. Skip.
# INFO     502 consists of a single batch or is too small. Skip.
# INFO     503 consists of a single batch or is too small. Skip.
# INFO     504 consists of a single batch or is too small. Skip.
# INFO     505 consists of a single batch or is too small. Skip.
# INFO     506 consists of a single batch or is too small. Skip.
# INFO     507 consists of a single batch or is too small. Skip.
# INFO     508 consists of a single batch or is too small. Skip.
# INFO     509 consists of a single batch or is too small. Skip.
# INFO     510 consists of a single batch or is too small. Skip.
# INFO     511 consists of a single batch or is too small. Skip.
# INFO     512 consists of a single batch or is too small. Skip.
# INFO     513 consists of a single batch or is too small. Skip.
# INFO     514 consists of a single batch or is too small. Skip.
# INFO     515 consists of a single batch or is too small. Skip.
# INFO     516 consists of a single batch or is too small. Skip.
# INFO     518 consists of a single batch or is too small. Skip.
# INFO     519 consists of a single batch or is too small. Skip.
# INFO     520 consists of a single batch or is too small. Skip.
# INFO     521 consists of a single batch or is too small. Skip.
# INFO     523 consists of a single batch or is too small. Skip.
# INFO     524 consists of a single batch or is too small. Skip.
# INFO     525 consists of a single batch or is too small. Skip.
# INFO     526 consists of a single batch or is too small. Skip.
# INFO     527 consists of a single batch or is too small. Skip.
# INFO     528 consists of a single batch or is too small. Skip.
# INFO     529 consists of a single batch or is too small. Skip.
# INFO     530 consists of a single batch or is too small. Skip.
# INFO     531 consists of a single batch or is too small. Skip.
# INFO     532 consists of a single batch or is too small. Skip.
# INFO     533 consists of a single batch or is too small. Skip.
# INFO     534 consists of a single batch or is too small. Skip.
# INFO     535 consists of a single batch or is too small. Skip.
# INFO     536 consists of a single batch or is too small. Skip.
# INFO     537 consists of a single batch or is too small. Skip.
# INFO     538 consists of a single batch or is too small. Skip.
# INFO     539 consists of a single batch or is too small. Skip.
# INFO     540 consists of a single batch or is too small. Skip.
# INFO     542 consists of a single batch or is too small. Skip.
# INFO     543 consists of a single batch or is too small. Skip.
# INFO     544 consists of a single batch or is too small. Skip.
# INFO     545 consists of a single batch or is too small. Skip.
# INFO     546 consists of a single batch or is too small. Skip.
# INFO     547 consists of a single batch or is too small. Skip.
# INFO     548 consists of a single batch or is too small. Skip.
# INFO     549 consists of a single batch or is too small. Skip.
# INFO     550 consists of a single batch or is too small. Skip.
# INFO     551 consists of a single batch or is too small. Skip.
# INFO     552 consists of a single batch or is too small. Skip.
# INFO     553 consists of a single batch or is too small. Skip.
# INFO     554 consists of a single batch or is too small. Skip.
# INFO     555 consists of a single batch or is too small. Skip.
# INFO     556 consists of a single batch or is too small. Skip.
# INFO     557 consists of a single batch or is too small. Skip.
# INFO     558 consists of a single batch or is too small. Skip.
# INFO     559 consists of a single batch or is too small. Skip.
# INFO     560 consists of a single batch or is too small. Skip.
# INFO     561 consists of a single batch or is too small. Skip.
# INFO     562 consists of a single batch or is too small. Skip.
# INFO     563 consists of a single batch or is too small. Skip.
# INFO     564 consists of a single batch or is too small. Skip.
# INFO     565 consists of a single batch or is too small. Skip.
# INFO     566 consists of a single batch or is too small. Skip.
# INFO     567 consists of a single batch or is too small. Skip.
# INFO     568 consists of a single batch or is too small. Skip.
# INFO     569 consists of a single batch or is too small. Skip.
# INFO     570 consists of a single batch or is too small. Skip.
# INFO     571 consists of a single batch or is too small. Skip.
# INFO     572 consists of a single batch or is too small. Skip.
# INFO     573 consists of a single batch or is too small. Skip.
# INFO     574 consists of a single batch or is too small. Skip.
# INFO     575 consists of a single batch or is too small. Skip.
# INFO     576 consists of a single batch or is too small. Skip.
# INFO     577 consists of a single batch or is too small. Skip.
# INFO     578 consists of a single batch or is too small. Skip.
# INFO     579 consists of a single batch or is too small. Skip.
# INFO     580 consists of a single batch or is too small. Skip.
# INFO     581 consists of a single batch or is too small. Skip.
# INFO     582 consists of a single batch or is too small. Skip.
# INFO     583 consists of a single batch or is too small. Skip.
# INFO     584 consists of a single batch or is too small. Skip.
# INFO     585 consists of a single batch or is too small. Skip.
# INFO     586 consists of a single batch or is too small. Skip.
# INFO     587 consists of a single batch or is too small. Skip.
# INFO     588 consists of a single batch or is too small. Skip.
# INFO     589 consists of a single batch or is too small. Skip.
# INFO     590 consists of a single batch or is too small. Skip.
# INFO     591 consists of a single batch or is too small. Skip.
# INFO     592 consists of a single batch or is too small. Skip.
# INFO     593 consists of a single batch or is too small. Skip.
# INFO     594 consists of a single batch or is too small. Skip.
# INFO     595 consists of a single batch or is too small. Skip.
# INFO     596 consists of a single batch or is too small. Skip.
# INFO     597 consists of a single batch or is too small. Skip.
# INFO     598 consists of a single batch or is too small. Skip.
# INFO     599 consists of a single batch or is too small. Skip.
# INFO     600 consists of a single batch or is too small. Skip.
# INFO     601 consists of a single batch or is too small. Skip.
# INFO     602 consists of a single batch or is too small. Skip.
# INFO     603 consists of a single batch or is too small. Skip.
# INFO     604 consists of a single batch or is too small. Skip.
# INFO     605 consists of a single batch or is too small. Skip.
# INFO     606 consists of a single batch or is too small. Skip.
# INFO     607 consists of a single batch or is too small. Skip.
# INFO     608 consists of a single batch or is too small. Skip.
# INFO     609 consists of a single batch or is too small. Skip.
# /home/gilberthan/anaconda3/envs/py311/lib/python3.11/site-packages/scib_metrics/_kbet.py:181: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   comp_size = pd.value_counts(labs)
# INFO     610 consists of a single batch or is too small. Skip.
# INFO     611 consists of a single batch or is too small. Skip.
# INFO     612 consists of a single batch or is too small. Skip.
# INFO     613 consists of a single batch or is too small. Skip.
# INFO     614 consists of a single batch or is too small. Skip.
# INFO     615 consists of a single batch or is too small. Skip.
# INFO     616 consists of a single batch or is too small. Skip.
# INFO     617 consists of a single batch or is too small. Skip.
# INFO     618 consists of a single batch or is too small. Skip.
# INFO     619 consists of a single batch or is too small. Skip.
# INFO     620 consists of a single batch or is too small. Skip.
# INFO     621 consists of a single batch or is too small. Skip.
# INFO     622 consists of a single batch or is too small. Skip.
# INFO     623 consists of a single batch or is too small. Skip.
# INFO     624 consists of a single batch or is too small. Skip.
# INFO     625 consists of a single batch or is too small. Skip.
# INFO     626 consists of a single batch or is too small. Skip.
# INFO     627 consists of a single batch or is too small. Skip.
# INFO     628 consists of a single batch or is too small. Skip.
# INFO     629 consists of a single batch or is too small. Skip.
# INFO     630 consists of a single batch or is too small. Skip.
# INFO     632 consists of a single batch or is too small. Skip.
# INFO     633 consists of a single batch or is too small. Skip.
# INFO     634 consists of a single batch or is too small. Skip.
# INFO     635 consists of a single batch or is too small. Skip.
# INFO     636 consists of a single batch or is too small. Skip.
# INFO     637 consists of a single batch or is too small. Skip.
# INFO     638 consists of a single batch or is too small. Skip.
# INFO     639 consists of a single batch or is too small. Skip.
# INFO     640 consists of a single batch or is too small. Skip.
# INFO     641 consists of a single batch or is too small. Skip.
# INFO     642 consists of a single batch or is too small. Skip.
# INFO     643 consists of a single batch or is too small. Skip.
# INFO     644 consists of a single batch or is too small. Skip.
# INFO     645 consists of a single batch or is too small. Skip.
# INFO     646 consists of a single batch or is too small. Skip.
# INFO     647 consists of a single batch or is too small. Skip.
# INFO     648 consists of a single batch or is too small. Skip.
# INFO     649 consists of a single batch or is too small. Skip.
# INFO     650 consists of a single batch or is too small. Skip.
# INFO     651 consists of a single batch or is too small. Skip.
# INFO     652 consists of a single batch or is too small. Skip.
# INFO     654 consists of a single batch or is too small. Skip.
# INFO     655 consists of a single batch or is too small. Skip.
# INFO     656 consists of a single batch or is too small. Skip.
# INFO     657 consists of a single batch or is too small. Skip.
# INFO     658 consists of a single batch or is too small. Skip.
# INFO     659 consists of a single batch or is too small. Skip.
# INFO     660 consists of a single batch or is too small. Skip.
# INFO     661 consists of a single batch or is too small. Skip.
# INFO     662 consists of a single batch or is too small. Skip.
# INFO     663 consists of a single batch or is too small. Skip.
# INFO     664 consists of a single batch or is too small. Skip.
# INFO     665 consists of a single batch or is too small. Skip.
# INFO     666 consists of a single batch or is too small. Skip.
# INFO     667 consists of a single batch or is too small. Skip.
# INFO     668 consists of a single batch or is too small. Skip.
# INFO     669 consists of a single batch or is too small. Skip.
# INFO     670 consists of a single batch or is too small. Skip.
# INFO     671 consists of a single batch or is too small. Skip.
# INFO     672 consists of a single batch or is too small. Skip.
# INFO     673 consists of a single batch or is too small. Skip.
# INFO     674 consists of a single batch or is too small. Skip.
# INFO     675 consists of a single batch or is too small. Skip.
# INFO     676 consists of a single batch or is too small. Skip.
# INFO     677 consists of a single batch or is too small. Skip.
# INFO     678 consists of a single batch or is too small. Skip.
# INFO     679 consists of a single batch or is too small. Skip.
# INFO     680 consists of a single batch or is too small. Skip.
# INFO     681 consists of a single batch or is too small. Skip.
# INFO     682 consists of a single batch or is too small. Skip.
# INFO     683 consists of a single batch or is too small. Skip.
# INFO     684 consists of a single batch or is too small. Skip.
# INFO     685 consists of a single batch or is too small. Skip.
# INFO     686 consists of a single batch or is too small. Skip.
# INFO     687 consists of a single batch or is too small. Skip.
# INFO     688 consists of a single batch or is too small. Skip.
# INFO     690 consists of a single batch or is too small. Skip.
# INFO     691 consists of a single batch or is too small. Skip.
# INFO     692 consists of a single batch or is too small. Skip.
# INFO     693 consists of a single batch or is too small. Skip.
# INFO     694 consists of a single batch or is too small. Skip.
# INFO     695 consists of a single batch or is too small. Skip.
# INFO     696 consists of a single batch or is too small. Skip.
# INFO     697 consists of a single batch or is too small. Skip.
# INFO     698 consists of a single batch or is too small. Skip.
# INFO     699 consists of a single batch or is too small. Skip.
# INFO     700 consists of a single batch or is too small. Skip.
# INFO     701 consists of a single batch or is too small. Skip.
# INFO     702 consists of a single batch or is too small. Skip.
# INFO     703 consists of a single batch or is too small. Skip.
# INFO     704 consists of a single batch or is too small. Skip.
# INFO     705 consists of a single batch or is too small. Skip.
# INFO     706 consists of a single batch or is too small. Skip.
# INFO     707 consists of a single batch or is too small. Skip.
# INFO     708 consists of a single batch or is too small. Skip.
# INFO     709 consists of a single batch or is too small. Skip.
# INFO     710 consists of a single batch or is too small. Skip.
# INFO     711 consists of a single batch or is too small. Skip.
# INFO     712 consists of a single batch or is too small. Skip.
# INFO     713 consists of a single batch or is too small. Skip.
# INFO     714 consists of a single batch or is too small. Skip.
# INFO     715 consists of a single batch or is too small. Skip.
# INFO     716 consists of a single batch or is too small. Skip.
# INFO     717 consists of a single batch or is too small. Skip.
# INFO     718 consists of a single batch or is too small. Skip.
# INFO     719 consists of a single batch or is too small. Skip.
# INFO     721 consists of a single batch or is too small. Skip.
# INFO     722 consists of a single batch or is too small. Skip.
# INFO     723 consists of a single batch or is too small. Skip.
# INFO     724 consists of a single batch or is too small. Skip.
# INFO     725 consists of a single batch or is too small. Skip.
# INFO     726 consists of a single batch or is too small. Skip.
# INFO     727 consists of a single batch or is too small. Skip.
# INFO     728 consists of a single batch or is too small. Skip.
# INFO     729 consists of a single batch or is too small. Skip.
# INFO     730 consists of a single batch or is too small. Skip.
# INFO     731 consists of a single batch or is too small. Skip.
# INFO     732 consists of a single batch or is too small. Skip.
# INFO     733 consists of a single batch or is too small. Skip.
# INFO     734 consists of a single batch or is too small. Skip.
# INFO     735 consists of a single batch or is too small. Skip.
# INFO     736 consists of a single batch or is too small. Skip.
# INFO     737 consists of a single batch or is too small. Skip.
# INFO     738 consists of a single batch or is too small. Skip.
# INFO     739 consists of a single batch or is too small. Skip.
# INFO     740 consists of a single batch or is too small. Skip.
# INFO     741 consists of a single batch or is too small. Skip.
# INFO     742 consists of a single batch or is too small. Skip.
# INFO     743 consists of a single batch or is too small. Skip.
# INFO     744 consists of a single batch or is too small. Skip.
# INFO     745 consists of a single batch or is too small. Skip.
# INFO     746 consists of a single batch or is too small. Skip.
# INFO     747 consists of a single batch or is too small. Skip.
# INFO     748 consists of a single batch or is too small. Skip.
# INFO     749 consists of a single batch or is too small. Skip.
# INFO     750 consists of a single batch or is too small. Skip.
# INFO     751 consists of a single batch or is too small. Skip.
# INFO     752 consists of a single batch or is too small. Skip.
# INFO     753 consists of a single batch or is too small. Skip.
# INFO     754 consists of a single batch or is too small. Skip.
# INFO     755 consists of a single batch or is too small. Skip.
# INFO     756 consists of a single batch or is too small. Skip.
# INFO     757 consists of a single batch or is too small. Skip.
# INFO     758 consists of a single batch or is too small. Skip.
# INFO     759 consists of a single batch or is too small. Skip.
# INFO     760 consists of a single batch or is too small. Skip.
# INFO     761 consists of a single batch or is too small. Skip.
# INFO     762 consists of a single batch or is too small. Skip.
# INFO     763 consists of a single batch or is too small. Skip.
# INFO     764 consists of a single batch or is too small. Skip.
# INFO     765 consists of a single batch or is too small. Skip.
# INFO     766 consists of a single batch or is too small. Skip.
# INFO     767 consists of a single batch or is too small. Skip.
# INFO     768 consists of a single batch or is too small. Skip.
# INFO     769 consists of a single batch or is too small. Skip.
# INFO     770 consists of a single batch or is too small. Skip.
# INFO     771 consists of a single batch or is too small. Skip.
# INFO     772 consists of a single batch or is too small. Skip.
# INFO     773 consists of a single batch or is too small. Skip.
# INFO     774 consists of a single batch or is too small. Skip.
# INFO     776 consists of a single batch or is too small. Skip.
# INFO     777 consists of a single batch or is too small. Skip.
# INFO     778 consists of a single batch or is too small. Skip.
# INFO     779 consists of a single batch or is too small. Skip.
# INFO     780 consists of a single batch or is too small. Skip.
# INFO     781 consists of a single batch or is too small. Skip.
# INFO     782 consists of a single batch or is too small. Skip.
# INFO     783 consists of a single batch or is too small. Skip.
# INFO     784 consists of a single batch or is too small. Skip.
# INFO     785 consists of a single batch or is too small. Skip.
# INFO     786 consists of a single batch or is too small. Skip.
# INFO     787 consists of a single batch or is too small. Skip.
# INFO     788 consists of a single batch or is too small. Skip.
# INFO     789 consists of a single batch or is too small. Skip.
# INFO     790 consists of a single batch or is too small. Skip.
# INFO     791 consists of a single batch or is too small. Skip.
# INFO     792 consists of a single batch or is too small. Skip.
# INFO     793 consists of a single batch or is too small. Skip.
# INFO     794 consists of a single batch or is too small. Skip.
# INFO     795 consists of a single batch or is too small. Skip.
# INFO     796 consists of a single batch or is too small. Skip.
# INFO     797 consists of a single batch or is too small. Skip.
# INFO     798 consists of a single batch or is too small. Skip.
# INFO     799 consists of a single batch or is too small. Skip.
# INFO     800 consists of a single batch or is too small. Skip.
# INFO     801 consists of a single batch or is too small. Skip.
# INFO     802 consists of a single batch or is too small. Skip.
# INFO     803 consists of a single batch or is too small. Skip.
# INFO     804 consists of a single batch or is too small. Skip.
# INFO     805 consists of a single batch or is too small. Skip.
# INFO     806 consists of a single batch or is too small. Skip.
# INFO     807 consists of a single batch or is too small. Skip.
# INFO     808 consists of a single batch or is too small. Skip.
# INFO     809 consists of a single batch or is too small. Skip.
# INFO     811 consists of a single batch or is too small. Skip.
# INFO     812 consists of a single batch or is too small. Skip.
# INFO     813 consists of a single batch or is too small. Skip.
# INFO     814 consists of a single batch or is too small. Skip.
# INFO     815 consists of a single batch or is too small. Skip.
# INFO     816 consists of a single batch or is too small. Skip.
# INFO     817 consists of a single batch or is too small. Skip.
# INFO     818 consists of a single batch or is too small. Skip.
# INFO     819 consists of a single batch or is too small. Skip.
# INFO     820 consists of a single batch or is too small. Skip.
# INFO     821 consists of a single batch or is too small. Skip.
# INFO     823 consists of a single batch or is too small. Skip.
# INFO     824 consists of a single batch or is too small. Skip.
# INFO     825 consists of a single batch or is too small. Skip.
# INFO     826 consists of a single batch or is too small. Skip.
# INFO     827 consists of a single batch or is too small. Skip.
# INFO     828 consists of a single batch or is too small. Skip.
# INFO     829 consists of a single batch or is too small. Skip.
# INFO     830 consists of a single batch or is too small. Skip.
# INFO     831 consists of a single batch or is too small. Skip.
# INFO     832 consists of a single batch or is too small. Skip.
# INFO     833 consists of a single batch or is too small. Skip.
# INFO     834 consists of a single batch or is too small. Skip.
# INFO     835 consists of a single batch or is too small. Skip.
# INFO     836 consists of a single batch or is too small. Skip.
# INFO     837 consists of a single batch or is too small. Skip.
# INFO     838 consists of a single batch or is too small. Skip.
# INFO     839 consists of a single batch or is too small. Skip.
# INFO     840 consists of a single batch or is too small. Skip.
# INFO     841 consists of a single batch or is too small. Skip.
# INFO     842 consists of a single batch or is too small. Skip.
# INFO     843 consists of a single batch or is too small. Skip.
# INFO     844 consists of a single batch or is too small. Skip.
# INFO     845 consists of a single batch or is too small. Skip.
# INFO     846 consists of a single batch or is too small. Skip.
# INFO     847 consists of a single batch or is too small. Skip.
# INFO     848 consists of a single batch or is too small. Skip.
# INFO     849 consists of a single batch or is too small. Skip.
# INFO     850 consists of a single batch or is too small. Skip.
# INFO     851 consists of a single batch or is too small. Skip.
# INFO     852 consists of a single batch or is too small. Skip.
# INFO     853 consists of a single batch or is too small. Skip.
# INFO     854 consists of a single batch or is too small. Skip.
# INFO     855 consists of a single batch or is too small. Skip.
# INFO     856 consists of a single batch or is too small. Skip.
# INFO     857 consists of a single batch or is too small. Skip.
# INFO     858 consists of a single batch or is too small. Skip.
# INFO     859 consists of a single batch or is too small. Skip.
# INFO     860 consists of a single batch or is too small. Skip.
# INFO     861 consists of a single batch or is too small. Skip.
# INFO     862 consists of a single batch or is too small. Skip.
# INFO     863 consists of a single batch or is too small. Skip.
# INFO     864 consists of a single batch or is too small. Skip.
# INFO     865 consists of a single batch or is too small. Skip.
# INFO     866 consists of a single batch or is too small. Skip.
# INFO     867 consists of a single batch or is too small. Skip.
# INFO     868 consists of a single batch or is too small. Skip.
# INFO     869 consists of a single batch or is too small. Skip.
# INFO     870 consists of a single batch or is too small. Skip.
# INFO     871 consists of a single batch or is too small. Skip.
# INFO     872 consists of a single batch or is too small. Skip.
# INFO     873 consists of a single batch or is too small. Skip.
# INFO     874 consists of a single batch or is too small. Skip.
# INFO     875 consists of a single batch or is too small. Skip.
# INFO     876 consists of a single batch or is too small. Skip.
# INFO     877 consists of a single batch or is too small. Skip.
# INFO     878 consists of a single batch or is too small. Skip.
# INFO     879 consists of a single batch or is too small. Skip.
# INFO     880 consists of a single batch or is too small. Skip.
# INFO     881 consists of a single batch or is too small. Skip.
# INFO     882 consists of a single batch or is too small. Skip.
# INFO     883 consists of a single batch or is too small. Skip.
# INFO     884 consists of a single batch or is too small. Skip.
# INFO     885 consists of a single batch or is too small. Skip.
# INFO     886 consists of a single batch or is too small. Skip.
# INFO     887 consists of a single batch or is too small. Skip.
# INFO     888 consists of a single batch or is too small. Skip.
# INFO     889 consists of a single batch or is too small. Skip.
# INFO     890 consists of a single batch or is too small. Skip.
# INFO     891 consists of a single batch or is too small. Skip.
# INFO     892 consists of a single batch or is too small. Skip.
# INFO     893 consists of a single batch or is too small. Skip.
# INFO     894 consists of a single batch or is too small. Skip.
# INFO     895 consists of a single batch or is too small. Skip.
# INFO     896 consists of a single batch or is too small. Skip.
# INFO     897 consists of a single batch or is too small. Skip.
# INFO     898 consists of a single batch or is too small. Skip.
# INFO     899 consists of a single batch or is too small. Skip.
# INFO     900 consists of a single batch or is too small. Skip.
# INFO     901 consists of a single batch or is too small. Skip.
# INFO     902 consists of a single batch or is too small. Skip.
# INFO     903 consists of a single batch or is too small. Skip.
# INFO     904 consists of a single batch or is too small. Skip.
# ...
# INFO     5466 consists of a single batch or is too small. Skip.
# INFO     5467 consists of a single batch or is too small. Skip.
# INFO     5468 consists of a single batch or is too small. Skip.
# INFO     5469 consists of a single batch or is too small. Skip.
# INFO     5470 consists of a single batch or is too small. Skip.
# INFO     5471 consists of a single batch or is too small. Skip.
# INFO     5472 consists of a single batch or is too small. Skip.
# INFO     5473 consists of a single batch or is too small. Skip.
# INFO     5474 consists of a single batch or is too small. Skip.
# INFO     5475 consists of a single batch or is too small. Skip.
# INFO     5476 consists of a single batch or is too small. Skip.
# INFO     5477 consists of a single batch or is too small. Skip.
# INFO     5478 consists of a single batch or is too small. Skip.
# INFO     5479 consists of a single batch or is too small. Skip.
# INFO     5480 consists of a single batch or is too small. Skip.
# INFO     5481 consists of a single batch or is too small. Skip.
# INFO     5482 consists of a single batch or is too small. Skip.
# INFO     5483 consists of a single batch or is too small. Skip.
# INFO     5484 consists of a single batch or is too small. Skip.
# INFO     5485 consists of a single batch or is too small. Skip.
# INFO     5486 consists of a single batch or is too small. Skip.
# INFO     5487 consists of a single batch or is too small. Skip.
# INFO     5488 consists of a single batch or is too small. Skip.
# INFO     5489 consists of a single batch or is too small. Skip.
# INFO     5490 consists of a single batch or is too small. Skip.
# INFO     5491 consists of a single batch or is too small. Skip.
# INFO     5492 consists of a single batch or is too small. Skip.
# INFO     5493 consists of a single batch or is too small. Skip.
# INFO     5494 consists of a single batch or is too small. Skip.
# INFO     5495 consists of a single batch or is too small. Skip.
# INFO     5496 consists of a single batch or is too small. Skip.
# INFO     5497 consists of a single batch or is too small. Skip.
# INFO     5498 consists of a single batch or is too small. Skip.
# INFO     5499 consists of a single batch or is too small. Skip.
# INFO     5500 consists of a single batch or is too small. Skip.
# INFO     5501 consists of a single batch or is too small. Skip.
# INFO     5502 consists of a single batch or is too small. Skip.
# INFO     5503 consists of a single batch or is too small. Skip.
# INFO     5504 consists of a single batch or is too small. Skip.
# INFO     5505 consists of a single batch or is too small. Skip.
# INFO     5506 consists of a single batch or is too small. Skip.
# INFO     5507 consists of a single batch or is too small. Skip.
# INFO     5508 consists of a single batch or is too small. Skip.
# INFO     5509 consists of a single batch or is too small. Skip.
# INFO     5510 consists of a single batch or is too small. Skip.
# INFO     5511 consists of a single batch or is too small. Skip.
# INFO     5512 consists of a single batch or is too small. Skip.
# INFO     5513 consists of a single batch or is too small. Skip.
# INFO     5514 consists of a single batch or is too small. Skip.
# INFO     5515 consists of a single batch or is too small. Skip.
# INFO     5516 consists of a single batch or is too small. Skip.
# INFO     5517 consists of a single batch or is too small. Skip.
# INFO     5518 consists of a single batch or is too small. Skip.
# INFO     5519 consists of a single batch or is too small. Skip.
# INFO     5520 consists of a single batch or is too small. Skip.
# INFO     5521 consists of a single batch or is too small. Skip.
# INFO     5522 consists of a single batch or is too small. Skip.
# INFO     5523 consists of a single batch or is too small. Skip.
# INFO     5524 consists of a single batch or is too small. Skip.
# INFO     5525 consists of a single batch or is too small. Skip.
# INFO     5526 consists of a single batch or is too small. Skip.
# INFO     5527 consists of a single batch or is too small. Skip.
# INFO     5528 consists of a single batch or is too small. Skip.
# INFO     5529 consists of a single batch or is too small. Skip.
# INFO     5530 consists of a single batch or is too small. Skip.
# INFO     5531 consists of a single batch or is too small. Skip.
# INFO     5534 consists of a single batch or is too small. Skip.
# INFO     5535 consists of a single batch or is too small. Skip.
# INFO     5536 consists of a single batch or is too small. Skip.
# INFO     5537 consists of a single batch or is too small. Skip.
# INFO     5538 consists of a single batch or is too small. Skip.
# INFO     5539 consists of a single batch or is too small. Skip.
# INFO     5540 consists of a single batch or is too small. Skip.
# INFO     5541 consists of a single batch or is too small. Skip.
# INFO     5542 consists of a single batch or is too small. Skip.
# INFO     5543 consists of a single batch or is too small. Skip.
# INFO     5544 consists of a single batch or is too small. Skip.
# INFO     5545 consists of a single batch or is too small. Skip.
# INFO     5546 consists of a single batch or is too small. Skip.
# INFO     5547 consists of a single batch or is too small. Skip.
# INFO     5548 consists of a single batch or is too small. Skip.
# INFO     5549 consists of a single batch or is too small. Skip.
# INFO     5551 consists of a single batch or is too small. Skip.
# INFO     5552 consists of a single batch or is too small. Skip.
# INFO     5553 consists of a single batch or is too small. Skip.
# INFO     5554 consists of a single batch or is too small. Skip.
# INFO     5555 consists of a single batch or is too small. Skip.
# INFO     5556 consists of a single batch or is too small. Skip.
# INFO     5557 consists of a single batch or is too small. Skip.
# INFO     5558 consists of a single batch or is too small. Skip.
# INFO     5559 consists of a single batch or is too small. Skip.
# INFO     5560 consists of a single batch or is too small. Skip.
# INFO     5561 consists of a single batch or is too small. Skip.
# INFO     5563 consists of a single batch or is too small. Skip.
# INFO     5565 consists of a single batch or is too small. Skip.
# INFO     5566 consists of a single batch or is too small. Skip.
# INFO     5567 consists of a single batch or is too small. Skip.
# INFO     5568 consists of a single batch or is too small. Skip.
# INFO     5569 consists of a single batch or is too small. Skip.
# INFO     5570 consists of a single batch or is too small. Skip.
# INFO     5571 consists of a single batch or is too small. Skip.
# INFO     5572 consists of a single batch or is too small. Skip.
# INFO     5573 consists of a single batch or is too small. Skip.
# INFO     5574 consists of a single batch or is too small. Skip.
# INFO     5575 consists of a single batch or is too small. Skip.
# INFO     5576 consists of a single batch or is too small. Skip.
# INFO     5577 consists of a single batch or is too small. Skip.
# INFO     5578 consists of a single batch or is too small. Skip.
# INFO     5579 consists of a single batch or is too small. Skip.
# INFO     5580 consists of a single batch or is too small. Skip.
# INFO     5581 consists of a single batch or is too small. Skip.
# INFO     5582 consists of a single batch or is too small. Skip.
# INFO     5583 consists of a single batch or is too small. Skip.
# INFO     5584 consists of a single batch or is too small. Skip.
# INFO     5585 consists of a single batch or is too small. Skip.
# INFO     5586 consists of a single batch or is too small. Skip.
# INFO     5587 consists of a single batch or is too small. Skip.
# INFO     5588 consists of a single batch or is too small. Skip.
# INFO     5589 consists of a single batch or is too small. Skip.
# INFO     5590 consists of a single batch or is too small. Skip.
# INFO     5591 consists of a single batch or is too small. Skip.
# INFO     5592 consists of a single batch or is too small. Skip.
# INFO     5593 consists of a single batch or is too small. Skip.
# INFO     5594 consists of a single batch or is too small. Skip.
# INFO     5595 consists of a single batch or is too small. Skip.
# INFO     5596 consists of a single batch or is too small. Skip.
# INFO     5597 consists of a single batch or is too small. Skip.
# INFO     5598 consists of a single batch or is too small. Skip.
# INFO     5599 consists of a single batch or is too small. Skip.
# INFO     5600 consists of a single batch or is too small. Skip.
# INFO     5601 consists of a single batch or is too small. Skip.
# INFO     5602 consists of a single batch or is too small. Skip.
# INFO     5603 consists of a single batch or is too small. Skip.
# INFO     5604 consists of a single batch or is too small. Skip.
# INFO     5605 consists of a single batch or is too small. Skip.
# INFO     5606 consists of a single batch or is too small. Skip.
# INFO     5607 consists of a single batch or is too small. Skip.
# INFO     5608 consists of a single batch or is too small. Skip.

# %%
bm.get_results()

# %%
bm.plot_results_table()
matplotlib.pyplot.savefig("../../results/preIntergration/20241018_hyperpara/20241019_grid_hypertune_metric.pdf")
